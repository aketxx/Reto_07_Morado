# %%
import pandas as pd
import numpy as np

# %%
datos = pd.read_excel("C:\\Users\\eider\\Downloads\\información_préstamos.xlsx")

# %%
#Copia de seguridad del dataset original

df = datos.copy()

# %%
#Revisión inicial de estructura

df.shape
# Out:
# (255347, 19)

# %%
df.head()
# Out:
#        ID  Edad  Ingresos  Monto_Inicial  Scoring_Crediticio  Meses_Empleo  \
# 0  S97R7X    18     61628          83011                 397           113
# 1  T3ZE0N    69     19485          25474                 784            46
# 2  RLGTBY    50     82410          68642                 486            14
# 3  BZ86CV    64    132974         208339                 308            10
# 4  5OD75M    62     51411         113847                 412            47
#
#    Num_Creditos  Ratio_Interes  Duracion  Ratio_Deuda_Ingresos  \
# 0             1           8.06        48                  0.45
# 1             2          15.04        48                  0.15
# 2             3          21.96        12                  0.71
# 3             1          24.26        12                  0.61
# 4             2           5.73        36                  0.70
#
#               Estudios Tipo_Jornada_Laboral Estado_Civil  Posesion_Hipoteca  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    255347 non-null  object
#  1   Edad                  255347 non-null  int64
#  2   Ingresos              255347 non-null  int64
#  3   Monto_Inicial         255347 non-null  int64
#  4   Scoring_Crediticio    255347 non-null  int64
#  5   Meses_Empleo          255347 non-null  int64
#  6   Num_Creditos          255347 non-null  int64
#  7   Ratio_Interes         255347 non-null  float64
#  8   Duracion              255347 non-null  int64
#  9   Ratio_Deuda_Ingresos  255347 non-null  float64
#  10  Estudios              255347 non-null  object
#  11  Tipo_Jornada_Laboral  255347 non-null  object
#  12  Estado_Civil          255347 non-null  object
#  13  Posesion_Hipoteca     255347 non-null  int64
# ...

# %%
#Comprobación de valores nulos

df.isnull().sum()
# Out:
# ID                      0
# Edad                    0
# Ingresos                0
# Monto_Inicial           0
# Scoring_Crediticio      0
# Meses_Empleo            0
# Num_Creditos            0
# Ratio_Interes           0
# Duracion                0
# Ratio_Deuda_Ingresos    0
# Estudios                0
# Tipo_Jornada_Laboral    0
# Estado_Civil            0
# Posesion_Hipoteca       0
# Personas_Cargo          0
# Proposito               0
# Fiador                  0
# Impago                  0
# Prima                   0
# dtype: int64

# %% [markdown]
# No se detectan valores nulos en las variables clave, por lo que no ha sido necesario aplicar técnicas de imputación.

# %%
# Duplicados

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# ID                       object
# Edad                      int64
# Ingresos                  int64
# Monto_Inicial             int64
# Scoring_Crediticio        int64
# Meses_Empleo              int64
# Num_Creditos              int64
# Ratio_Interes           float64
# Duracion                  int64
# Ratio_Deuda_Ingresos    float64
# Estudios                 object
# Tipo_Jornada_Laboral     object
# Estado_Civil             object
# Posesion_Hipoteca         int64
# Personas_Cargo            int64
# Proposito                object
# Fiador                    int64
# Impago                    int64
# Prima                   float64
# dtype: object

# %% [markdown]
# Se comprueba la consistencia de los tipos de datos para garantizar la correcta aplicación de los modelos financieros posteriores.

# %%
# Conversión de variables categóricas

variables_categoricas = [
    "Estudios",
    "Tipo_Jornada_Laboral",
    "Estado_Civil",
    "Proposito"
]

for col in variables_categoricas:
    df[col] = df[col].astype("category")

# %% [markdown]
# Las variables cualitativas se convierten al tipo category para reflejar correctamente su naturaleza no numérica y optimizar su tratamiento en los modelos posteriores.

# %%
# Conversión de variables binarias a tipo numérico compacto

variables_binarias = [
    "Posesion_Hipoteca",
    "Fiador",
    "Impago"
]

for col in variables_binarias:
    df[col] = df[col].astype("int8")

# %% [markdown]
# Las variables binarias se convierten a tipo numérico para garantizar su correcta interpretación en los modelos predictivos y en los cálculos financieros.

# %%
df.describe()
# Out:
#                 Edad       Ingresos  Monto_Inicial  Scoring_Crediticio  \
# count  255347.000000  255347.000000  255347.000000       255347.000000
# mean       43.498306   82499.304597  127578.865512          574.264346
# std        14.990258   38963.013729   70840.706142          158.903867
# min        18.000000   15000.000000    5000.000000          300.000000
# 25%        31.000000   48825.500000   66156.000000          437.000000
# 50%        43.000000   82466.000000  127556.000000          574.000000
# 75%        56.000000  116219.000000  188985.000000          712.000000
# max        69.000000  149999.000000  249999.000000          849.000000
#
#         Meses_Empleo   Num_Creditos  Ratio_Interes       Duracion  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       59.541976       2.501036      13.492773      36.025894
# std        34.643376       1.117018       6.636443      16.969330
# ...

# %%
df["Interes_Anual"] = df["Ratio_Interes"] / 100

# %%
df.shape
# Out:
# (255347, 20)

# %%
# Tratamiento de outliers

variables_numericas = [
    "Edad", "Ingresos", "Monto_Inicial", "Scoring_Crediticio",
    "Meses_Empleo", "Num_Creditos", "Ratio_Interes",
    "Duracion", "Ratio_Deuda_Ingresos", "Prima"
]

for col in variables_numericas:
    q1 = df[col].quantile(0.01)
    q99 = df[col].quantile(0.99)
    df[col] = df[col].clip(lower=q1, upper=q99)

# %% [markdown]
# Este tratamiento resulta especialmente relevante en variables como ingresos, capital inicial o ratios financieros, donde valores atípicos pueden distorsionar estimaciones de cuotas, intereses y probabilidades de impago

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    255347 non-null  object
#  1   Edad                  255347 non-null  int64
#  2   Ingresos              255347 non-null  float64
#  3   Monto_Inicial         255347 non-null  float64
#  4   Scoring_Crediticio    255347 non-null  int64
#  5   Meses_Empleo          255347 non-null  int64
#  6   Num_Creditos          255347 non-null  int64
#  7   Ratio_Interes         255347 non-null  float64
#  8   Duracion              255347 non-null  int64
#  9   Ratio_Deuda_Ingresos  255347 non-null  float64
#  10  Estudios              255347 non-null  category
#  11  Tipo_Jornada_Laboral  255347 non-null  category
#  12  Estado_Civil          255347 non-null  category
#  13  Posesion_Hipoteca     255347 non-null  int8
# ...

# %%
df.describe(include="all")
# Out:
#             ID           Edad       Ingresos  Monto_Inicial  \
# count   255347  255347.000000  255347.000000  255347.000000
# unique  255347            NaN            NaN            NaN
# top     G7MCLO            NaN            NaN            NaN
# freq         1            NaN            NaN            NaN
# mean       NaN      43.498306   82499.594269  127578.910542
# std        NaN      14.990258   38939.988662   70798.937401
# min        NaN      18.000000   16357.920000    7443.000000
# 25%        NaN      31.000000   48825.500000   66156.000000
# 50%        NaN      43.000000   82466.000000  127556.000000
# 75%        NaN      56.000000  116219.000000  188985.000000
# max        NaN      69.000000  148661.000000  247545.540000
#
#         Scoring_Crediticio   Meses_Empleo   Num_Creditos  Ratio_Interes  \
# count        255347.000000  255347.000000  255347.000000  255347.000000
# unique                 NaN            NaN            NaN            NaN
# ...

# %%
df.head()
# Out:
#        ID  Edad  Ingresos  Monto_Inicial  Scoring_Crediticio  Meses_Empleo  \
# 0  S97R7X    18   61628.0        83011.0                 397           113
# 1  T3ZE0N    69   19485.0        25474.0                 784            46
# 2  RLGTBY    50   82410.0        68642.0                 486            14
# 3  BZ86CV    64  132974.0       208339.0                 308            10
# 4  5OD75M    62   51411.0       113847.0                 412            47
#
#    Num_Creditos  Ratio_Interes  Duracion  Ratio_Deuda_Ingresos  \
# 0             1           8.06        48                  0.45
# 1             2          15.04        48                  0.15
# 2             3          21.96        12                  0.71
# 3             1          24.26        12                  0.61
# 4             2           5.73        36                  0.70
#
#               Estudios Tipo_Jornada_Laboral Estado_Civil  Posesion_Hipoteca  \
# ...

# %%
df.to_csv("datos_prestamos_limpios.csv", index=False, encoding="utf-8")
